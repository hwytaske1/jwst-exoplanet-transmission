# %%
import numpy as np
import matplotlib.pyplot as plt
import astropy
import lightkurve

print("Everything is working 🚀")
# Out:
# Matplotlib is building the font cache; this may take a moment.
# Everything is working 🚀
# C:\Users\hwyta\Documents\Research\jwst-exoplanet-transmission\.venv\Lib\site-packages\lightkurve\prf\__init__.py:7: UserWarning: Warning: the tpfmodel submodule is not available without oktopus installed, which requires a current version of autograd. See #1452 for details.
#   warnings.warn(

# %%
from astropy.io import fits

print("Ready for JWST data analysis")
# Out:
# Ready for JWST data analysis

# %%
from astroquery.mast import Observations

obs = Observations.query_object("WASP-39 b", radius="0.02 deg")
obs[:5]
# Out:
# <Table masked=True length=5>
# intentType obs_collection provenance_name instrument_name project filters wave_region ... mtFlag  srcDen   obsid   wave_min wave_max distance
#   str11         str5           str31           str13        str4   str13     str16    ...  bool  float64    str9   float64  float64  float64
# ---------- -------------- --------------- --------------- ------- ------- ----------- ... ------ ------- --------- -------- -------- --------
#    science           TESS            SPOC      Photometer    TESS    TESS     Optical ...  False     nan  87584531    600.0   1000.0      0.0
#    science           TESS            SPOC      Photometer    TESS    TESS     Optical ...  False     nan 262964751    600.0   1000.0      0.0
#    science           TESS            SPOC      Photometer    TESS    TESS     OPTICAL ...  False     nan 314948059    600.0   1000.0      0.0
#    science           TESS            SPOC      Photometer    TESS    TESS     Optical ...  False     nan  87494793    600.0   1000.0      0.0
#    science           TESS            SPOC      Photometer    TESS    TESS     Optical ...  False     nan 266954188    600.0   1000.0      0.0

# %%
jwst = obs[obs['obs_collection'] == 'JWST']
jwst
# Out:
# <Table masked=True length=29>
#  intentType obs_collection provenance_name instrument_name project ...  srcDen   obsid   wave_min      wave_max           distance
#    str11         str5           str31           str13        str4  ... float64    str9   float64       float64            float64
# ----------- -------------- --------------- --------------- ------- ... ------- --------- -------- ------------------ ------------------
#     science           JWST         CALJWST     NIRISS/SOSS    JWST ...     nan  87742481    600.0             2800.0                0.0
#     science           JWST         CALJWST    NIRCAM/GRISM    JWST ...     nan  87682152   2430.0 4013.0000000000005                0.0
#     science           JWST         CALJWST    NIRSPEC/SLIT    JWST ...     nan 233644122   2870.0             5140.0                0.0
#     science           JWST         CALJWST    NIRSPEC/SLIT    JWST ...     nan 233647483    600.0             5300.0                0.0
#     science           JWST         CALJWST     NIRISS/SOSS    JWST ...     nan  87742159    600.0             2800.0                0.0
#     science           JWST         CALJWST    NIRCAM/IMAGE    JWST ...     nan  87681967    700.0             2201.0                0.0
#         ...            ...             ...             ...     ... ...     ...       ...      ...                ...                ...
# calibration           JWST         CALJWST    NIRSPEC/SLIT    JWST ...     nan  87769094      nan                nan 2.9671778064855863
#     science           JWST         CALJWST   MIRI/SLITLESS    JWST ...     nan 116644217   9000.0            11000.0 12.241934634996621
#     science           JWST         CALJWST    NIRCAM/IMAGE    JWST ...     nan  87681961    700.0             2201.0 38.331779661421436
#     science           JWST         CALJWST    NIRCAM/IMAGE    JWST ...     nan  87681970    700.0             2201.0 38.331779661421436
#     science           JWST         CALJWST    NIRCAM/IMAGE    JWST ...     nan  87681960    700.0             2201.0 38.331779661421436
#     science           JWST         CALJWST    NIRCAM/IMAGE    JWST ...     nan  87681963    700.0             2201.0 38.331779661421436
